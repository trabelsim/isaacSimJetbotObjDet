# %% [markdown]
# Connecting to the graphical simulation interface by providing the .usd file of the simulated env.

# %%
import getpass
user = getpass.getuser()
from omni.isaac.kit import SimulationApp
# Set the path below to your desired nucleus server
simulation_app = SimulationApp({"livesync_usd": f'omniverse://localhost/Projects/trabelsi/jetbot.usd'})
print("Hi")
# Out:
# Passing the following args to the base kit application:  ['-f', '/home/student/.local/share/jupyter/runtime/kernel-bf284c0a-0fd4-478f-9fb1-740551c9be62.json']
# [Warning] [omni.kit.app.plugin] No crash reporter present, dumps uploading isn't available.
# [Info] [carb] Logging to file: /home/student/.local/share/ov/pkg/isaac_sim-2021.2.1/kit/logs/Kit/Isaac-Sim/2021.2/kit_20220502_232613.log
# 2022-05-02 21:26:13 s] [Warning] [omni.ext.plugin] [ext: omni.jetbot.opencv] Extensions config 'extension.toml' doesn't exist anywhere in '/home/student/.local/share/ov/pkg/isaac_sim-2021.2.1/exts/omni.jetbot.opencv/**'
# [0.045s] [ext: omni.kit.pipapi-0.0.0] startup
# [0.054s] [ext: omni.kit.pip_archive-0.0.0] startup
# [0.058s] [ext: omni.isaac.pip_archive-0.1.0] startup
# [0.218s] [ext: omni.usd.config-1.0.0] startup
# [0.220s] [ext: omni.usd.libs-1.0.0] startup
# [0.362s] [ext: omni.stats-0.0.0] startup
# [0.365s] [ext: omni.gpu_foundation-0.0.0] startup
# [0.370s] [ext: omni.kit.async_engine-0.0.0] startup
# [0.371s] [ext: omni.kit.loop-isaac-0.1.0] startup
# [0.372s] [ext: omni.assets.plugins-0.0.0] startup
# [0.372s] [ext: omni.appwindow-1.0.0] startup
# 2022-05-02 21:26:13 s] [Error] [carb.windowing-glfw.plugin] GLFW initialization failed.
# 2022-05-02 21:26:13 s] [Error] [carb] Failed to startup plugin carb.windowing-glfw.plugin (interfaces: [carb::windowing::IGLContext v1.0],[carb::windowing::IWindowing v1.2]) (impl: carb.windowing-glfw.plugin)
# [0.375s] [ext: omni.client-0.1.0] startup
# [0.382s] [ext: omni.kit.renderer.core-0.0.0] startup
#
# |---------------------------------------------------------------------------------------------|
# | Driver Version: 470.103     | Graphics API: Vulkan
# |=============================================================================================|
# | GPU | Name                             | Active | LDA | GPU Memory | Vendor-ID | LUID       |
# |     |                                  |        |     |            | Device-ID | UUID       |
# |---------------------------------------------------------------------------------------------|
# | 0   | NVIDIA GeForce RTX 3070          | Yes: 0 |     | 8438    MB | 10de      | 0          |
# |     |                                  |        |     |            | 2488      | 68a19bb3.. |
# |=============================================================================================|
# | OS: Linux colima, Version: 5.4.0-105-generic
# | Processor: 11th Gen Intel(R) Core(TM) i9-11900K @ 3.50GHz | Cores: Unknown | Logical: 16
# |---------------------------------------------------------------------------------------------|
# | Total Memory (MB): 64146 | Free Memory: 41386
# | Total Page/Swap (MB): 61034 | Free Page/Swap: 61034
# |---------------------------------------------------------------------------------------------|
# 2022-05-02 21:26:13 s] [Warning] [gpu.foundation.plugin] Different GPUs have different availalbe VRAM. The texture streaming system will be limited to the lower VRAM number
# 2022-05-02 21:26:13 s] [Error] [carb.windowing-glfw.plugin] GLFW initialization failed.
# 2022-05-02 21:26:13 s] [Error] [carb] Failed to startup plugin carb.windowing-glfw.plugin (interfaces: [carb::windowing::IGLContext v1.0],[carb::windowing::IWindowing v1.2]) (impl: carb.windowing-glfw.plugin)
# 2022-05-02 21:26:13 s] [Error] [carb.windowing-glfw.plugin] GLFW initialization failed.
# 2022-05-02 21:26:13 s] [Error] [carb] Failed to startup plugin carb.windowing-glfw.plugin (interfaces: [carb::windowing::IGLContext v1.0],[carb::windowing::IWindowing v1.2]) (impl: carb.windowing-glfw.plugin)
# 2022-05-02 21:26:13 s] [Error] [carb.windowing-glfw.plugin] GLFW initialization failed.
# 2022-05-02 21:26:13 s] [Error] [carb] Failed to startup plugin carb.windowing-glfw.plugin (interfaces: [carb::windowing::IGLContext v1.0],[carb::windowing::IWindowing v1.2]) (impl: carb.windowing-glfw.plugin)
# 2022-05-02 21:26:13 s] [Error] [carb.windowing-glfw.plugin] GLFW initialization failed.
# 2022-05-02 21:26:13 s] [Error] [carb] Failed to startup plugin carb.windowing-glfw.plugin (interfaces: [carb::windowing::IGLContext v1.0],[carb::windowing::IWindowing v1.2]) (impl: carb.windowing-glfw.plugin)
# 2022-05-02 21:26:13 s] [Error] [carb.windowing-glfw.plugin] GLFW initialization failed.
# 2022-05-02 21:26:13 s] [Error] [carb] Failed to startup plugin carb.windowing-glfw.plugin (interfaces: [carb::windowing::IGLContext v1.0],[carb::windowing::IWindowing v1.2]) (impl: carb.windowing-glfw.plugin)
# [0.842s] [ext: omni.kit.test-0.0.0] startup
# [0.922s] [ext: omni.ui-2.5.3] startup
# [0.933s] [ext: omni.kit.mainwindow-0.0.0] startup
# [0.935s] [ext: omni.kit.uiapp-0.0.0] startup
# [0.936s] [ext: omni.usd.schema.physics-1.0.0] startup
# 2022-05-02 21:26:14 s] [Warning] [omni.ext.impl._internal] There is already a module 'pxr.UsdPhysics' in '/home/student/.local/share/ov/pkg/isaac_sim-2021.2.1/kit/extscore/omni.usd.schema.physics/pxr/UsdPhysics/__init__.py'. Can't import another module with the same name in public space from '/home/student/.local/share/ov/pkg/isaac_sim-2021.2.1/kit/extsPhysics/omni.usd.schema.physics'.
# 2022-05-02 21:26:14 s] [Warning] [omni.ext.impl._internal] There is already a module 'usd.schema.physics' in '/home/student/.local/share/ov/pkg/isaac_sim-2021.2.1/kit/extscore/omni.usd.schema.physics/usd/schema/physics/__init__.py'. Can't import another module with the same name in public space from '/home/student/.local/share/ov/pkg/isaac_sim-2021.2.1/kit/extsPhysics/omni.usd.schema.physics'.
# [0.947s] [ext: omni.usd.schema.isaac-0.1.1] startup
# [0.976s] [ext: omni.usd.schema.anim-0.0.0] startup
# [0.996s] [ext: omni.usd.schema.physx-0.0.0] startup
# [1.017s] [ext: omni.usd.schema.audio-0.0.0] startup
# [1.022s] [ext: omni.usd.schema.semantics-0.0.0] startup
# [1.026s] [ext: omni.kit.commands-0.0.0] startup
# [1.035s] [ext: carb.audio-0.1.0] startup
# [1.037s] [ext: omni.timeline-1.0.2] startup
# [1.040s] [ext: omni.hydra.scene_delegate-0.1.0] startup
# [1.046s] [ext: omni.usd-1.4.5] startup
# [1.065s] [ext: omni.kit.asset_converter-1.1.43] startup
# [1.084s] [ext: omni.kit.widget.graph-1.1.4] startup
# [1.089s] [ext: omni.kvdb-0.0.0] startup
# [1.097s] [ext: omni.usdphysics-1.3.14] startup
# [1.098s] [ext: omni.convexdecomposition-1.3.14] startup
# [1.106s] [ext: omni.kit.window.extensions-1.0.2] startup
# [1.119s] [ext: omni.localcache-0.0.0] startup
# [1.127s] [ext: omni.kit.menu.utils-1.0.2] startup
# [1.133s] [ext: omni.physx-1.3.14-5.1] startup
# 2022-05-02 21:26:14 [1,139ms] [Warning] [omni.kvdb.plugin] wasn't able to load the meta database, trying to repair it ...
# 2022-05-02 21:26:14 [1,199ms] [Warning] [omni.kvdb.plugin] repair failed
# [1.206s] [ext: omni.kit.menu.create-1.0.1] startup
# [1.211s] [ext: omni.kit.window.drop_support-1.0.0] startup
# [1.212s] [ext: omni.services.facilities.base-1.0.0] startup
# [1.214s] [ext: omni.kit.window.popup_dialog-2.0.4] startup
# [1.216s] [ext: omni.kit.material.library-1.2.3] startup
# [1.279s] [ext: omni.kit.widget.versioning-1.3.4] startup
# [1.281s] [ext: omni.kit.context_menu-1.3.2] startup
# [1.357s] [ext: omni.renderer-rtx-0.0.0] startup
# [1.358s] [ext: omni.hydra.rtx-0.1.0] startup
# [1.363s] [ext: omni.kit.numpy.common-0.1.0] startup
# [1.438s] [ext: omni.kit.window.viewport-0.0.0] startup
# [2.123s] [ext: omni.services.core-1.1.1] startup
# [2.216s] [ext: omni.services.transport.client.base-1.1.0] startup
# [2.217s] [ext: omni.services.transport.server.base-1.0.0] startup
# [2.218s] [ext: omni.services.client-0.2.3] startup
# [2.325s] [ext: omni.services.transport.server.http-1.0.0] startup
# 2022-05-02 21:26:15 [2,512ms] [Warning] [omni.services.transport.server.http.server] http server was meant to start on 8211 but port is taken, starting on port 8062 instead
# [2.519s] [ext: omni.kit.search_core-1.0.0] startup
# [2.521s] [ext: omni.services.transport.client.http_async-1.0.0] startup
# [2.882s] [ext: omni.kit.agent-0.1.0] startup
# [2.883s] [ext: omni.kit.widget.filebrowser-2.2.20] startup
# [2.888s] [ext: omni.kit.widget.path_field-2.0.3] startup
# [2.889s] [ext: omni.kit.thumbnails.images-0.1.0] startup
# [2.892s] [ext: omni.kit.notification_manager-1.0.0] startup
# [2.894s] [ext: omni.kit.widget.browser_bar-2.0.2] startup
# [2.895s] [ext: omni.kit.window.property-1.6.2] startup
# [2.896s] [ext: omni.kit.window.filepicker-2.4.12] startup
# [3.045s] [ext: omni.isaac.dynamic_control-0.1.8] startup
# [3.052s] [ext: omni.isaac.lula-0.1.0] startup
# [3.059s] [ext: omni.isaac.ui-0.1.2] startup
# [3.061s] [ext: omni.isaac.core-0.1.12] startup
# [3.106s] [ext: omni.isaac.surface_gripper-0.1.0] startup
# [3.111s] [ext: omni.kit.stage_templates-1.0.6Simulation App Starting
# Saving a temp livesync stage at  omniverse://localhost/Projects/trabelsi/jetbot.usd  ...Done.
# Simulation App Startup Complete
# Hi

# %%
import carb
import omni.ext
import omni.appwindow
import gc
import numpy as np
from omni.isaac.jetbot import Jetbot
from omni.isaac.jetbot.controllers import DifferentialController
from omni.isaac.examples.base_sample import BaseSample
from omni.isaac.core.utils.viewports import set_camera_view

# %% [markdown]
# Create the scene:
#     Add the jetbot
#     Add a sphere object
#     Declare a simple controller for the jetbot
#     Setup the viewport to the jetbot camera

# %%
from omni.isaac.jetbot import Jetbot
from omni.isaac.core import World
from omni.isaac.core.objects import DynamicSphere
from omni.isaac.jetbot.controllers import DifferentialController
import numpy as np

my_world = World(stage_units_in_meters=0.01)
my_jetbot = my_world.scene.add(Jetbot(prim_path="/World/Jetbot", name="my_jetbot", position=np.array([0, 0.0, 2.0])))
my_sphere = my_world.scene.add(DynamicSphere(prim_path="/World/sphere", name="my_sphere", position=np.array([100,0,4.0])))
my_world.scene.add_default_ground_plane()
my_controller = DifferentialController(name="simple_control")
my_world.reset()
jetbot_camera_path = "/World/Jetbot/chassis/rgb_camera/jetbot_camera"
viewport = omni.kit.viewport.get_default_viewport_window()
viewport.set_active_camera(jetbot_camera_path)
i = 0
# Out:
# ] startup
# [3.114s] [ext: omni.isaac.motion_planning-0.1.7] startup
# [3.120s] [ext: omni.isaac.kit-0.1.2] startup
# [3.121s] [ext: omni.isaac.motion_generation-0.1.2] startup
# [3.124s] [ext: omni.isaac.kaya-0.0.0] startup
# [3.125s] [ext: omni.isaac.universal_robots-0.1.1] startup
# [3.126s] [ext: omni.kit.window.file-1.3.5] startup
# [3.228s] [ext: omni.kit.widget.settings-1.0.0] startup
# [3.229s] [ext: omni.kit.widget.stage-2.6.8] startup
# [3.232s] [ext: omni.kit.window.content_browser-2.4.10] startup
# [3.342s] [ext: omni.kit.window.preferences-1.1.5] startup
# [3.369s] [ext: omni.kit.usd_undo-0.1.0] startup
# [3.371s] [ext: omni.kit.widget.stage_icons-1.0.2] startup
# [3.372s] [ext: omni.kit.property.usd-3.11.4] startup
# [3.395s] [ext: omni.debugdraw-0.1.0] startup
# [3.399s] [ext: omni.physx.commands-1.3.14-5.1] startup
# [3.406s] [ext: omni.kit.window.stage-2.3.4] startup
# [3.412s] [ext: omni.physx.ui-1.3.14-5.1] startup
# [3.428s] [ext: omni.kit.property.material-1.7.2] startup
# [3.434s] [ext: omni.kit.window.toolbar-1.2.1] startup
# [3.438s] [ext: omni.physx.demos-1.3.14-5.1] startup
# [3.446s] [ext: omni.kit.property.physx-0.1.0] startup
# [3.490s] [ext: omni.physx.tests-1.3.14-5.1] startup
# [3.604s] [ext: omni.physx.vehicle-1.3.14-5.1] startup
# [3.619s] [ext: omni.physx.cct-1.3.14-5.1] startup
# [3.630s] [ext: omni.isaac.franka-0.0.0] startup
# [3.633s] [ext: omni.physx.bundle-1.3.14-5.1] startup
# [3.633s] [ext: omni.isaac.utils-0.1.10] startup
# [3.636s] [ext: omni.kit.window.status_bar-0.1.0] startup
# [3.637s] [ext: omni.kit.widget.layers-1.5.12] startup
# [3.650s] [ext: omni.kit.property.skel-1.0.0] startup
# [3.651s] [ext: omni.kit.widget.prompt-1.0.0] startup
# [3.652s] [ext: omni.kit.property.layer-1.1.2] startup
# [3.653s] [ext: omni.kit.property.camera-1.0.3] startup
# [3.654s] [ext: omni.kit.property.transform-1.0.2] startup
# [3.656s] [ext: omni.kit.property.geometry-1.2.0] startup
# [3.657s] [ext: omni.kit.property.light-1.0.4] startup
# [3.658s] [ext: omni.kit.property.audio-1.0.5] startup
# [3.659s] [ext: omni.isaac.contact_sensor-0.1.0] startup
# [3.663s] [ext: omni.kit.window.script_editor-1.5.0] startup
# [3.664s] [ext: omni.kit.property.bundle-1.2.4] startup
# [3.664s] [ext: omni.rtx.window.settings-0.6.0] startup
# [3.670s] [ext: omni.syntheticdata-0.1.6] startup
# [3.837s] [ext: omni.isaac.debug_draw-0.1.1] startup
# [3.840s] [ext: omni.kit.profiler.window-1.3.3] startup
# [3.852s] [ext: omni.rtx.settings.core-0.5.4] startup
# [3.857s] [ext: omni.isaac.range_sensor-0.1.5] startup
# [3.877s] [ext: omni.isaac.python_app-0.0.0] startup
# [3.878s] [ext: omni.kit.widget.live-0.1.0] startup
# [3.879s] [ext: omni.kit.window.console-0.1.0] startup
# [3.881s] [ext: omni.isaac.dofbot-0.1.1] startup
# [3.882s] [ext: omni.isaac.synthetic_utils-0.1.5] startup
# [3.888s] [ext: omni.isaac.urdf-0.1.13] startup
# [3.908s] [ext: omni.kit.primitive.mesh-1.0.0] startup
# [3.911s] [ext: omni.isaac.occupancy_map-0.1.1] startup
# [3.930s] [ext: omni.isaac.dr-0.1.8] startup
# [3.935s] [ext: omni.isaac.imu_sensor-0.1.1] startup
# [3.938s] [ext: omni.isaac.jetbot-0.0.0] startup
# [3.939s] [ext: omni.isaac.sim.python-2021.2.1] startup
# [3.939s] app started
# 2022-05-02 21:26:17 [4,265ms] [Warning] [omni.usd] Default value for render setting "/rtx/iray/rendermode" not found
# 2022-05-02 21:26:17 [4,266ms] [Warning] [omni.usd] Default value for render setting "/rtx/verifyDriverVersion/enabled" not found
# 2022-05-02 21:26:17 [4,266ms] [Warning] [omni.usd] Default value for render setting "/rtx/shaderDb/cachePermutationIndex" not found
# 2022-05-02 21:26:17 [4,267ms] [Warning] [omni.usd] Default value for render setting "/rtx/resourcemanager/textureCachePath" not found
# 2022-05-02 21:26:19 [6,577ms] [Warning] [omni.ext-live.plugin] Omniverse Cache is disabled! It can be turned on in Omniverse System Monitor.
# 2022-05-02 21:26:26 [13,252ms] [Warning] [omni.hydra.scene_delegate.plugin] Calling setBypassRenderSkelMeshProcessing for prim /World/Jetbot/chassis/geometry/caster_ball_case_front that is not usdskel mesh type
# 2022-05-02 21:26:26 [13,708ms] [Warning] [gpu.foundation.plugin] Requesting texture to use texture streaming, but the se

# %%
# i = 0
# while simulation_app.is_running() and i<400:
#     my_world.step(render=True)
#     if my_world.is_playing():
#         if my_world.current_time_step_index == 0:
#             my_world.reset()
#             my_controller.reset()
#         if i >= 0 and i < 1000:
#             # forward
#             my_jetbot.apply_wheel_actions(my_controller.forward(command=[5, 0]))
#             print(my_jetbot.get_linear_velocity())
#         elif i >= 1000 and i < 1300:
#             # rotate
#             my_jetbot.apply_wheel_actions(my_controller.forward(command=[0.0, np.pi / 12]))
#             print(my_jetbot.get_angular_velocity())
#         elif i >= 1300 and i < 2000:
#             # forward
#             my_jetbot.apply_wheel_actions(my_controller.forward(command=[5, 0]))
#         elif i == 2000:
#             i = 0
#         i += 1
# Out:
# (0,0,0)
# (5.56277,-0.00623195,-0.00805265)
# (5.61765,-0.0112657,-0.000261838)
# (5.6182,-0.0166165,-0.000862178)
# (5.62229,-0.0126467,-0.000484598)
# (5.62142,-0.0142944,-0.000725242)
# (5.6192,-0.0147479,-0.00117199)
# (5.62219,-0.0171814,-0.000623184)
# (5.61809,-0.0130992,-0.000344903)
# (5.62145,-0.0150966,-0.000699304)
# (5.62263,-0.0164244,-0.00192916)
# (5.62239,-0.017458,-0.000681763)
# (5.62196,-0.0162567,-0.000798586)
# (5.62246,-0.0182709,-0.00074282)
# (5.61908,-0.0172397,-0.00155684)
# (5.62235,-0.018436,-0.000857639)
# (5.62187,-0.0156842,-0.00120309)
# (5.61873,-0.0198652,-0.000989985)
# (5.61859,-0.0174093,-0.00127551)
# (5.62207,-0.0186264,-0.00162956)
# (5.62217,-0.0181859,-0.00131276)
# (5.61829,-0.0186179,-0.00197531)
# (5.61842,-0.0181658,-0.00140371)
# (5.61819,-0.0191227,-0.00113373)
# (5.61922,-0.0189441,-0.00112623)
# (5.61795,-0.0194727,-0.00181205)
# (5.6193,-0.0193785,-0.00158633)
# (5.62178,-0.0194833,-0.00142277)
# (5.61912,-0.0193937,-0.00121789)
# (5.62166,-0.020294,-0.00163844)
# (5.61878,-0.0201881,-0.00225119)
# (5.62271,-0.0214959,-0.00202445)
# (5.61815,-0.0206206,-0.00191395)
# (5.6222,-0.0228663,-0.00185404)
# (5.62234,-0.0216707,-0.00187333)
# (5.61792,-0.0211239,-0.00220941)
# (5.61872,-0.0221546,-0.00155172)
# (5.618,-0.0239578,-0.00278937)
# (5.61877,-0.021891,-0.00198136)
# (5.62223,-0.0248131,-0.00209164)
# (5.61815,-0.0218439,-0.00214463)
# (5.62188,-0.0232939,-0.00225863)
# (5.61861,-0.0223187,-0.00191735)
# (5.6216,-0.024257,-0.00289311)
# (5.61858,-0.0228888,-0.00279828)
# (5.61813,-0.0268224,-0.00231618)
# (5.62158,-0.0256981,-0.00208098)
# (5.62169,-0.0264854,-0.0029769)
# (5.62201,-0.0246406,-0.00163567)
# (5.61717,-0.0241688,-0.00237621)
# (5.61776,-0.0254932,-0.00209991)
# (5.6212,-0.0279641,-0.00253852)
# (5.6211,-0.0265914,-0.00195709)
# (5.62116,-0.0272308,-0.00226808)
# (5.62138,-0.0276865,-0.00279942)
# (5.61709,-0.0282744,-0.00268524)
# (5.62203,-0.0272271,-0.002854)
# (5.61684,-0.0272038,-0.00248038)
# (5.61801,-0.027608,-0.00314864)
# (5.61661,-0.027767,-0.002193)
# (5.61728,-0.0280852,-0.00240309)
# (5.61635,-0.0285696,-0.00271137)
# (5.62044,-0.028809,-0.00187023)
# (5.61604,-0.0301318,-0.00219045)
# (5.62014,-0.0286281,-0.00200742)
# (5.62013,-0.030293,-0.00208667)
# (5.6165,-0.0299209,-0.002711)
# (5.6203,-0.0332601,-0.00216601)
# (5.61597,-0.0323128,-0.00236048)
# (5.61991,-0.032566,-0.0030756)
# (5.61966,-0.031901,-0.00209951)
# (5.6196,-0.0326382,-0.00332102)
# (5.61629,-0.0322682,-0.00206603)
# (5.61592,-0.0359145,-0.00288457)
# (5.61617,-0.0341931,-0.00298044)
# (5.61891,-0.0335194,-0.0021926)
# (5.61596,-0.0336134,-0.00212736)
# (5.61478,-0.0343126,-0.0021773)
# (5.61573,-0.0335279,-0.00172424)
# (5.61495,-0.0344014,-0.00257661)
# (5.61877,-0.0341924,-0.00140199)
# (5.61841,-0.0358866,-0.00179974)
# (5.61504,-0.0343757,-0.00151953)
# (5.61464,-0.0364543,-0.00155433)
# (5.61824,-0.0359879,-0.00155157)
# (5.61481,-0.0375784,-0.00183732)
# (5.61474,-0.0382538,-0.00131222)
# (5.61439,-0.0389279,-0.00225476)
# (5.61457,-0.0365454,-0.00128783)
# (5.61794,-0.0394197,-0.00152048)
# (5.61847,-0.0353215,-0.00174918)
# (5.61405,-0.038917,-0.00166999)
# (5.61832,-0.0385085,-0.00180439)
# (5.61341,-0.0394773,-0.000981021)
# (5.61441,-0.0394382,-0.00131921)
# (5.61352,-0.0410495,-0.0012073)
# (5.61349,-0.0402905,-0.00122876)
# (5.61747,-0.0434368,-0.00099628)
# (5.61739,-0.0398584,-0.00100537)
# (5.61752,-0.0433471,-0.00137645)
# (5.61402,-0.0391307,-0.000527372)
# (5.61657,-0.0417394,-0.000732833)
# (5.61315,-0.0428177,-0.000455947)
# (5.61276,-0.0442556,-0.000485814)
# (5.61388,-0.044083,-0.00126331)
# (5.61634,-0.0454364,-0.000617593)
# (5.6173,-0.0430786,-0.000641789)
# (5.61292,-0.0455004,-0.000792892)
# (5.61277,-0.0441855,-0.00031104)
# (5.61245,-0.0455789,-0.000684114)
# (5.61292,-0.0445976,-0.000328901)
# (5.61549,-0.0447877,-0.000184088)
# (5.6124,-0.0480204,-4.52242e-05)
# (5.61193,-0.0456865,-0.00046166)
# (5.61301,-0.0481391,0.000161297)
# (5.61182,-0.0465911,0.000186184)
# (5.61248,-0.0443138,0.000424412)
# (5.61195,-0.0510469,-0.000145858)
# (5.61306,-0.0488946,0.000550022)
# (5.61176,-0.0472895,0.000111611)
# (5.61223,-0.0495198,0.000370877)
# (5.61529,-0.04966,0.000113672)
# (5.61145,-0.0476889,0.000342867)
# (5.61185,-0.053598,0.000475401)
# (5.61276,-0.0496065,0.000654852)
# (5.6153,-0.0511182,0.000472525)
# (5.61173,-0.050327,0.000806457)
# (5.61138,-0.050596,0.000353129)
# (5.61145,-0.0509851,0.000634396)
# (5.61172,-0.0562953,0.000633527)
# (5.61171,-0.0513962,0.000706796)
# (5.61189,-0.0571974,0.000158736)
# (5.61536,-0.054067,0.00100344)
# (5.61504,-0.0537559,0.00107557)
# (5.61269,-0.053131,0.00143138)
# (5.61524,-0.0556679,0.00117822)
# (5.61595,-0.0550234,0.00100943)
# (5.61562,-0.0570824,0.000905769)
# (5.61516,-0.054399,0.00128887)
# (5.61075,-0.056185,0.00128262)
# (5.61247,-0.0563535,0.00108413)
# (5.61501,-0.0571044,0.00130485)
# (5.61543,-0.0581829,0.00147592)
# (5.61541,-0.0594532,0.0014051)
# (5.61193,-0.0597651,0.00163896)
# (5.6151,-0.0571791,0.00152402)
# (5.61155,-0.0581417,0.0012478)
# (5.61139,-0.0600747,0.00174514)
# (5.61133,-0.061176,0.00186752)
# (5.61129,-0.0582918,0.000981704)
# (5.61312,-0.0621272,0.00049134)
# (5.61221,-0.0631367,0.00193007)
# (5.61482,-0.0616766,0.00160743)
# (5.61623,-0.0631445,0.00234702)
# (5.61228,-0.0624946,0.00148077)
# (5.61603,-0.0641475,0.00190841)
# (5.61175,-0.0640167,0.00171373)
# (5.61228,-0.0641158,0.000861582)
# (5.61638,-0.0611643,0.00064945)
# (5.61196,-0.065711,0.00185771)
# (5.61264,-0.0648945,0.00220552)
# (5.61169,-0.0662788,0.00168215)
# (5.61225,-0.0673119,0.00167128)
# (5.6122,-0.0652544,0.00157076)
# (5.61328,-0.0685344,0.0014764)
# (5.61226,-0.0679123,0.0019676)
# (5.61218,-0.0687537,0.00210765)
# (5.61237,-0.0708703,0.00190219)
# (5.61365,-0.0670111,0.000330273)
# (5.61702,-0.0723504,0.000387034)
# (5.61713,-0.0716818,0.000937491)
# (5.61229,-0.0692469,0.00181761)
# (5.61291,-0.0718025,0.00182802)
# (5.61277,-0.0675692,0.00111979)
# (5.61325,-0.0701893,0.00212326)
# (5.61278,-0.0720217,0.0019009)
# (5.61328,-0.0717305,0.00154)
# (5.6129,-0.0733832,0.00107617)
# (5.61338,-0.0727628,0.00209051)
# (5.6171,-0.0745533,0.00210529)
# (5.61376,-0.0722301,0.00158796)
# (5.61357,-0.074206,0.00149875)
# (5.61394,-0.0733525,0.00194253)
# (5.61348,-0.0752917,0.000597356)
# (5.61455,-0.07655,0.00139481)
# (5.61449,-0.0795911,0.000838242)
# (5.6141,-0.0729795,0.00134313)
# (5.61451,-0.0792929,0.00128548)
# (5.61349,-0.0760213,0.00200787)
# (5.61391,-0.0749034,0.00116252)
# (5.61427,-0.0771144,0.00178649)
# (5.61517,-0.0809429,0.000971685)
# (5.61863,-0.0769215,0.00151664)
# (5.61484,-0.0777256,0.001341)
# (5.61473,-0.0780003,0.00108377)
# (5.6149,-0.0801881,0.00142679)
# (5.61513,-0.0788912,0.00175441)
# (5.61869,-0.0817266,3.8637e-05)
# (5.61476,-0.0789653,0.00168722)
# (5.61529,-0.0807962,0.00132321)
# (5.6155,-0.0805552,0.00139317)
# (5.619,-0.0803421,0.00112755)
# (5.61559,-0.0803835,0.000927794)
# (5.62,-0.0822382,0.00113561)
# (5.6155,-0.0807946,0.00119264)
# (5.61513,-0.0831741,0.000663135)
# (5.61651,-0.0821419,0.00120501)
# (5.61912,-0.0825615,0.000972714)
# (5.62017,-0.0846416,0.000381155)
# (5.61589,-0.084849,-1.91716e-05)
# (5.61673,-0.0819115,-0.000223525)
# (5.62011,-0.0855911,5.13472e-05)
# (5.61977,-0.0836616,0.00090144)
# (5.61658,-0.085672,0.000372346)
# (5.62047,-0.0860604,0.000294926)
# (5.61607,-0.0877983,-0.000381712)
# (5.61723,-0.0852276,0.000368747)
# (5.6161,-0.0883633,-0.0002392)
# (5.62067,-0.0852709,0.000782361)
# (5.6166,-0.0867798,-0.000191617)
# (5.61711,-0.0862218,0.000535131)
# (5.62106,-0.0906045,-8.91283e-05)
# (5.61725,-0.0890035,-0.000163414)
# (5.62133,-0.0892483,-1.14788e-05)
# (5.61732,-0.087762,-0.000335632)
# (5.62114,-0.0892553,-0.000236433)
# (5.61749,-0.0888462,0.000382097)
# (5.62019,-0.0896916,-0.000395832)
# (5.61768,-0.0899841,-0.000674877)
# (5.62042,-0.0892338,-0.00112798)
# (5.62066,-0.0912678,-0.000700989)
# (5.61807,-0.0923033,-0.00122627)
# (5.61802,-0.0911191,-0.000872231)
# (5.61673,-0.0911197,-0.000768748)
# (5.62262,-0.0908395,-0.00103843)
# (5.61732,-0.0934037,-0.00201152)
# (5.618,-0.0922758,-0.00166222)
# (5.61743,-0.0935179,-0.00100269)
# (5.61769,-0.091709,-0.000564265)
# (5.61827,-0.0926374,-0.0012447)
# (5.61756,-0.0928117,-0.000624709)
# (5.62122,-0.0924064,-0.00122976)
# (5.62332,-0.0935205,-0.00119731)
# (5.61797,-0.093521,-0.00128072)
# (5.6216,-0.0931089,-0.00146817)
# (5.61808,-0.0961401,-0.00163323)
# (5.61802,-0.0932267,-0.0010536)
# (5.6173,-0.0937673,-0.00189435)
# (5.61797,-0.0938697,-0.00151862)
# (5.61757,-0.0961272,-0.00209687)
# (5.61853,-0.094724,-0.00157686)
# (5.61708,-0.0970576,-0.00224649)
# (5.6218,-0.0975063,-0.00147054)
# (5.6179,-0.0970295,-0.0018518)
# (5.62163,-0.0964366,-0.00148127)
# (5.61788,-0.0974635,-0.00185519)
# (5.62214,-0.097074,-0.00193591)
# (5.61711,-0.0973693,-0.0021269)
# (5.61797,-0.0967336,-0.00227802)
# (5.61781,-0.100509,-0.0017166)
# (5.61791,-0.0972337,-0.00202738)
# (5.61713,-0.0986639,-0.0021369)
# (5.61862,-0.0977587,-0.00297559)
# (5.61783,-0.102011,-0.00262861)
# (5.6226,-0.0983133,-0.00370381)
# (5.61695,-0.0988525,-0.00211792)
# (5.61788,-0.0999366,-0.00322915)
# (5.62015,-0.0997879,-0.00214529)
# (5.62154,-0.100047,-0.00207214)
# (5.61645,-0.0993908,-0.0023271)
# (5.61739,-0.100362,-0.00251775)
# (5.61607,-0.103231,-0.00292883)
# (5.62135,-0.101113,-0.00206095)
# (5.61612,-0.100919,-0.00214349)
# (5.61745,-0.1011,-0.00223541)
# (5.61625,-0.100774,-0.00273172)
# (5.61995,-0.102678,-0.00250859)
# (5.61992,-0.102652,-0.00203991)
# (5.61684,-0.102813,-0.00271108)
# (5.61555,-0.102851,-0.00258763)
# (5.61773,-0.101547,-0.00343438)
# (5.6155,-0.104181,-0.0022792)
# (5.61769,-0.102597,-0.00390757)
# (5.61598,-0.105486,-0.00278394)
# (5.61993,-0.103489,-0.00199103)
# (5.61523,-0.10618,-0.00301382)
# (5.61982,-0.104961,-0.00276189)
# (5.61524,-0.107857,-0.00210596)
# (5.61513,-0.106723,-0.00271599)
# (5.61541,-0.109344,-0.00278601)
# (5.615,-0.105275,-0.00239388)
# (5.61494,-0.107073,-0.00221838)
# (5.61525,-0.106968,-0.00210468)
# (5.61478,-0.106389,-0.00220862)
# (5.61608,-0.107655,-0.00264921)
# (5.61505,-0.108843,-0.00272551)
# (5.61934,-0.108311,-0.00226575)
# (5.61494,-0.109969,-0.00219443)
# (5.61916,-0.107821,-0.00172797)
# (5.6144,-0.108899,-0.00201906)
# (5.61389,-0.111351,-0.00260707)
# (5.61362,-0.109502,-0.00206315)
# (5.61367,-0.112058,-0.00333251)
# (5.61299,-0.109374,-0.00219547)
# (5.61401,-0.10988,-0.00178282)
# (5.61442,-0.112958,-0.00226014)
# (5.61404,-0.110993,-0.00293149)
# (5.61287,-0.111865,-0.0015207)
# (5.61347,-0.111099,-0.00187547)
# (5.61276,-0.111524,-0.00192082)
# (5.61451,-0.111937,-0.00178222)
# (5.61338,-0.114649,-0.00181284)
# (5.61379,-0.113487,-0.00183262)
# (5.61299,-0.116414,-0.00223908)
# (5.61328,-0.113371,-0.00166756)
# (5.61298,-0.116285,-0.00226476)
# (5.61342,-0.113698,-0.00138611)
# (5.61245,-0.112944,-0.00137921)
# (5.61288,-0.116809,-0.00123259)
# (5.61247,-0.116736,-0.00106863)
# (5.61192,-0.117361,-0.0011565)
# (5.6161,-0.117566,-0.00127115)
# (5.61348,-0.116745,-0.000507058)
# (5.61598,-0.117441,-0.00119425)
# (5.61584,-0.116162,-0.000785683)
# (5.61212,-0.120441,-0.000953599)
# (5.61157,-0.117256,-0.00097214)
# (5.61554,-0.119926,-0.00057837)
# (5.61092,-0.119242,-0.00128117)
# (5.61161,-0.120251,-0.0013829)
# (5.61272,-0.120538,-0.000461284)
# (5.61575,-0.120411,-0.000428354)
# (5.61176,-0.119036,-0.000149492)
# (5.61128,-0.119744,-0.000323475)
# (5.61191,-0.119597,-0.00137577)
# (5.61072,-0.120701,-0.000261933)
# (5.611,-0.120741,-0.000509087)
# (5.6106,-0.121794,6.0825e-05)
# (5.61089,-0.11965,0.000211703)
# (5.61462,-0.122997,0.000182478)
# (5.60999,-0.122034,5.85143e-05)
# (5.61462,-0.122592,0.000262099)
# (5.61536,-0.124492,-8.87056e-05)
# (5.61017,-0.125453,0.00011489)
# (5.61044,-0.12496,0.000353518)
# (5.60973,-0.125084,0.000315842)
# (5.61046,-0.122947,0.000575853)
# (5.61403,-0.124384,0.000662167)
# (5.61006,-0.128541,0.000583277)
# (5.61043,-0.125919,9.24104e-05)
# (5.61055,-0.127087,0.000155695)
# (5.61432,-0.127338,0.000788038)
# (5.61013,-0.128198,0.000812154)
# (5.61342,-0.126944,0.00093782)
# (5.60978,-0.127744,0.000901986)
# (5.61064,-0.129475,0.00052463)
# (5.61021,-0.129413,0.000718629)
# (5.60967,-0.129663,0.000982981)
# (5.60859,-0.129593,0.000861374)
# (5.60929,-0.130663,0.0010682)
# (5.60822,-0.129466,0.00127508)
# (5.60969,-0.134437,0.000530777)
# (5.61396,-0.132869,0.000291813)
# (5.60999,-0.131549,0.00105563)
# (5.60834,-0.132593,0.00130648)
# (5.61468,-0.134533,0.00122416)
# (5.60837,-0.131998,0.00113912)
# (5.61354,-0.134027,0.0011012)
# (5.60824,-0.13386,0.00173129)
# (5.61347,-0.134345,0.00152405)
# (5.60902,-0.136748,0.00192919)
# (5.61301,-0.136475,0.00124139)
# (5.609,-0.139606,0.000403112)
# (5.61322,-0.137745,0.00141901)
# (5.60896,-0.135647,0.00173307)
# (5.61391,-0.139207,0.00170747)
# (5.60774,-0.138916,0.00185624)
# (5.61381,-0.13591,0.0012689)
# (5.609,-0.137384,0.00223887)
# (5.61006,-0.140516,0.00174722)
# (5.60909,-0.140652,0.00178147)
# (5.60991,-0.141155,0.00217635)
# (5.60939,-0.140668,0.0019481)
# (5.6107,-0.139628,0.000193203)
# (5.60909,-0.142342,0.0019013)
# (5.61046,-0.142104,0.00172485)
# (5.60949,-0.141081,0.00237869)
# (5.61326,-0.144014,0.00172649)
# (5.61429,-0.142053,0.00103916)
# (5.61079,-0.141956,0.00146475)
# (5.60992,-0.142134,0.00155222)
# (5.61371,-0.144905,0.0018549)
# (5.6094,-0.146918,0.00155961)
# (5.61074,-0.144001,0.0018581)
# (5.6098,-0.143994,0.00237688)
# (5.61006,-0.146879,0.00208424)
# (5.61518,-0.14616,0.00184295)
# (5.61022,-0.145172,0.00190524)
# (5.60988,-0.14791,0.00208219)
# (5.61012,-0.14788,0.00152442)

# %% [markdown]
# There are useful information, but below there is a better implementation with obj detection

# %%
import carb
import omni.kit
import numpy as np
import asyncio
import omni.syntheticdata._syntheticdata as gt
from omni.isaac.synthetic_utils import SyntheticDataHelper
from PIL import Image
my_world.reset()
from IPython.display import clear_output
import matplotlib.pyplot as plt

# stage = omni.usd.get_context().get_stage()
# settings_interface = carb.settings.acquire_settings_interface()
# viewport_interface = omni.kit.viewport.get_viewport_interface()

# sd_helper = SyntheticDataHelper()

# print(str(stage))
# print(str(settings_interface))
# print(str(viewport_interface))

# viewport_handle = viewport_interface.get_instance('Viewport')
# viewport_window = viewport_interface.get_viewport_window(viewport_handle)
# jetbot_camera_path = "/World/Jetbot/chassis/rgb_camera/jetbot_camera"
# viewport_window.set_active_camera(jetbot_camera_path)

i=0
# %matplotlib inline
while simulation_app.is_running() and i<10:
    my_world.step(render=True)
    clear_output(wait=True)
    if my_world.is_playing():
        gt = sd_helper.get_groundtruth(["rgb"], viewport_window)
        if my_world.current_time_step_index == 0:
            my_world.reset()
            my_controller.reset()
        if i >= 0 and i < 1000:
            # forward
            my_jetbot.apply_wheel_actions(my_controller.forward(command=[10, 0]))
            #print(my_jetbot.get_linear_velocity())
        elif i >= 1000 and i < 1300:
            # rotate
            my_jetbot.apply_wheel_actions(my_controller.forward(command=[0.0, np.pi / 12]))
            print(my_jetbot.get_angular_velocity())
        elif i >= 1300 and i < 2000:
            # forward
            my_jetbot.apply_wheel_actions(my_controller.forward(command=[5, 0]))
        elif i == 2000:
            i = 0
        i += 1
        plt.imshow(gt["rgb"])
        plt.show()

# %% [markdown]
# The scripts is a converted version of the algorithm implemented in C++ previously. It setups the active camera to jetbot's cam. It reads the configuration and weight files required for the DNN. It reads the image directly from the camera's viewport and converts it to blob to forward it in the network. Finally, if the confidence is higher than the threshold setup, it draws the rectangular and inserts a label next to the detected object. The image is plotted.

# %%
import cv2
from omni.isaac.synthetic_utils import SyntheticDataHelper
import omni.syntheticdata._syntheticdata as gt
import matplotlib.pyplot as plt
from IPython.display import clear_output
from PIL import Image
import asyncio
CLASSES = ["cone",
"cylinder",
"cuboid",
"sphere1"]

COLORS = np.random.uniform(0,255,size=(len(CLASSES),3))

stage = omni.usd.get_context().get_stage()
# settings_interface = carb.settings.acquire_settings_interface()
# Simulation - required to create the viewport instance
viewport_interface = omni.kit.viewport.get_viewport_interface()
# Simulation - required to transform the viewport view into an rgb image
sd_helper = SyntheticDataHelper()

# print(str(stage))
# print(str(settings_interface))
# print(str(viewport_interface))

#Simulation - getting the instance and be able to choose the jetbot camera
viewport_handle = viewport_interface.get_instance('Viewport')
viewport_window = viewport_interface.get_viewport_window(viewport_handle)
jetbot_camera_path = "/World/Jetbot/chassis/rgb_camera/jetbot_camera"
viewport_window.set_active_camera(jetbot_camera_path)

net = cv2.dnn.readNetFromTensorflow('data/graphs/frozen_inference_graph.pb', 'data/graphs/graph.pbtxt')
i=0
# Simulation - the condition is dependent on the simulation_app running
while simulation_app.is_running() and i<20:
    my_world.step(render=True)
    if my_world.is_playing():
        clear_output(wait=True) #clearing the jupyter output for updating the plot with a new image
        #Simulation - getting the rgb image from the viewport window
        gt = sd_helper.get_groundtruth(["rgb"], viewport_window)
        input_image = cv2.cvtColor(gt["rgb"], cv2.COLOR_RGBA2RGB)
        (h,w) = input_image.shape[:2]
        print("Image input size: " + str(h) + ", " + str(w))
        blob = cv2.dnn.blobFromImage(image=cv2.resize(input_image,(w,h)), scalefactor=1.0, size=(300,300), swapRB=True)

        net.setInput(blob)
        detections = net.forward()
        for j in np.arange(0, detections.shape[2]):
            confidence = detections[0,0,j,2]
            if confidence > 0.70:
                idx = int(detections[0,0,j,1])
                box = detections[0,0,j,3:7] * np.array([w,h,w,h])
                (startX, startY, endX, endY) = box.astype("int")
                print("Id: " + str(idx))
                label = "{}: {:.2f}%".format(CLASSES[idx-1], confidence*100)
                print(label)
                cv2.rectangle(input_image, (startX,startY), (endX,endY), COLORS[idx-1],2)
                y = startY - 15 if startY - 15 > 15 else startY + 15
                cv2.putText(input_image, label, (startX, y), cv2.FONT_HERSHEY_SIMPLEX, 0.5, COLORS[idx-1],2)
                plt.imshow(input_image)
                plt.show()
        if my_world.current_time_step_index == 0:
            my_world.reset()
            my_controller.reset()
        if i >= 0 and i < 1000:
            # Simulation - moving the jetbot forward
            my_jetbot.apply_wheel_actions(my_controller.forward(command=[10, 0]))
        i+=1
# Out:
# Image input size: 720, 1280
# Id: 4
# sphere1: 93.16%

# %%
my_world.reset()

# %%
simulation_app.close()
# Out:
# Simulation App Shutting Down
# ture will be created as a regular resource.
# [140.816s] [ext: omni.isaac.sim.python-2021.2.1] shutdown
# [140.816s] [ext: omni.physx.bundle-1.3.14-5.1] shutdown
# [140.816s] [ext: omni.physx.vehicle-1.3.14-5.1] shutdown
# [140.836s] [ext: omni.kit.property.physx-0.1.0] shutdown
# [140.849s] [ext: omni.physx.cct-1.3.14-5.1] shutdown
# [140.861s] [ext: omni.physx.demos-1.3.14-5.1] shutdown
# [140.872s] [ext: omni.physx.tests-1.3.14-5.1] shutdown
# [140.883s] [ext: omni.physx.ui-1.3.14-5.1] shutdown
# [140.897s] [ext: omni.physx.commands-1.3.14-5.1] shutdown
# [140.908s] [ext: omni.isaac.contact_sensor-0.1.0] shutdown
# [140.945s] [ext: omni.isaac.dofbot-0.1.1] shutdown
# [140.945s] [ext: omni.isaac.franka-0.0.0] shutdown
# [140.945s] [ext: omni.isaac.dr-0.1.8] shutdown
# [140.952s] [ext: omni.isaac.jetbot-0.0.0] shutdown
# [140.952s] [ext: omni.isaac.kaya-0.0.0] shutdown
# [140.952s] [ext: omni.isaac.universal_robots-0.1.1] shutdown
# [140.952s] [ext: omni.isaac.motion_generation-0.1.2] shutdown
# [140.952s] [ext: omni.isaac.motion_planning-0.1.7] shutdown
# [140.953s] [ext: omni.isaac.occupancy_map-0.1.1] shutdown
# [141.025s] [ext: omni.isaac.python_app-0.0.0] shutdown
# [141.025s] [ext: omni.isaac.range_sensor-0.1.5] shutdown
# [141.033s] [ext: omni.isaac.synthetic_utils-0.1.5] shutdown
# [141.033s] [ext: omni.isaac.surface_gripper-0.1.0] shutdown
# [141.033s] [ext: omni.isaac.utils-0.1.10] shutdown
# [141.069s] [ext: omni.isaac.core-0.1.12] shutdown
# [141.069s] [ext: omni.isaac.dynamic_control-0.1.8] shutdown
# [141.103s] [ext: omni.isaac.imu_sensor-0.1.1] shutdown
# [141.139s] [ext: omni.isaac.urdf-0.1.13] shutdown
# [141.181s] [ext: omni.physx-1.3.14-5.1] shutdown
# [141.192s] [ext: omni.convexdecomposition-1.3.14] shutdown
# [141.203s] [ext: omni.localcache-0.0.0] shutdown
# [141.214s] [ext: omni.kvdb-0.0.0] shutdown
# [141.224s] [ext: omni.usd.schema.physx-0.0.0] shutdown
# [141.235s] [ext: omni.usdphysics-1.3.14] shutdown
# [141.235s] [ext: omni.kit.property.bundle-1.2.4] shutdown
# [141.235s] [ext: omni.kit.property.audio-1.0.5] shutdown
# [141.235s] [ext: omni.kit.property.camera-1.0.3] shutdown
# [141.235s] [ext: omni.kit.property.geometry-1.2.0] shutdown
# [141.236s] [ext: omni.kit.property.light-1.0.4] shutdown
# [141.236s] [ext: omni.kit.property.material-1.7.2] shutdown
# [141.236s] [ext: omni.kit.property.skel-1.0.0] shutdown
# [141.236s] [ext: omni.kit.property.transform-1.0.2] shutdown
# [141.236s] [ext: omni.kit.property.usd-3.11.4] shutdown
# [141.239s] [ext: omni.kit.window.stage-2.3.4] shutdown
# [141.239s] [ext: omni.kit.widget.stage-2.6.8] shutdown
# [141.239s] [ext: omni.isaac.kit-0.1.2] shutdown
# [141.239s] [ext: omni.kit.asset_converter-1.1.43] shutdown
# [141.250s] [ext: omni.isaac.debug_draw-0.1.1] shutdown
# [141.250s] [ext: omni.debugdraw-0.1.0] shutdown
# [141.251s] [ext: omni.kit.primitive.mesh-1.0.0] shutdown
# [141.252s] [ext: omni.kit.property.layer-1.1.2] shutdown
# [141.252s] [ext: omni.kit.widget.layers-1.5.12] shutdown
# [141.253s] [ext: omni.kit.window.content_browser-2.4.10] shutdown
# [141.254s] [ext: omni.kit.window.file-1.3.5] shutdown
# [141.255s] [ext: omni.kit.stage_templates-1.0.6] shutdown
# [141.255s] [ext: omni.kit.widget.live-0.1.0] shutdown
# [141.256s] [ext: omni.kit.profiler.window-1.3.3] shutdown
# [141.266s] [ext: omni.kit.window.preferences-1.1.5] shutdown
# [141.269s] [ext: omni.rtx.settings.core-0.5.4] shutdown
# [141.271s] [ext: omni.rtx.window.settings-0.6.0] shutdown
# [141.271s] [ext: omni.kit.widget.settings-1.0.0] shutdown
# [141.271s] [ext: omni.kit.window.console-0.1.0] shutdown
# [141.271s] [ext: omni.isaac.ui-0.1.2] shutdown
# [141.271s] [ext: omni.kit.window.property-1.6.2] shutdown
# [141.271s] [ext: omni.kit.window.status_bar-0.1.0] shutdown
# [141.272s] [ext: omni.kit.window.toolbar-1.2.1] shutdown
# [141.272s] [ext: omni.syntheticdata-0.1.6] shutdown
# [141.272s] [ext: omni.kit.window.viewport-0.0.0] shutdown
# [142.894s] [ext: omni.kit.context_menu-1.3.2] shutdown
# [142.894s] [ext: omni.kit.material.library-1.2.3] shutdown
# [142.895s] [ext: omni.kit.menu.create-1.0.1] shutdown
# [142.895s] [ext: omni.usd-1.4.5] shutdown
# [142.907s] [ext: omni.usd.schema.physics-1.0.0] shutdown
# [142.918s] [ext: omni.isaac.lula-0.1.0] shutdown
# [142.918s] [ext: omni.isaac.pip_archive-0.1.0] shutdown
# [142.918s] [ext: omni.kit.window.drop_support-1.0.0] shutdown
# [142.918s] [ext: omni.kit.uiapp-0.0.0] shutdown
# [142.918s] [ext: omni.kit.widget.prompt-1.0.0] shutdown
# [142.918s] [ext: omni.kit.window.filepicker-2.4.12] shutdown
# [142.918s] [ext: omni.kit.notification_manager-1.0.0] shutdown
# [142.918s] [ext: omni.kit.widget.browser_bar-2.0.2] shutdown
# [142.918s] [ext: omni.kit.widget.filebrowser-2.2.20] shutdown
# [142.919s] [ext: omni.kit.window.extensions-1.0.2] shutdown
# [142.919s] [ext: omni.kit.widget.graph-1.1.4] shutdown
# [142.919s] [ext: omni.kit.widget.path_field-2.0.3] shutdown
# [142.919s] [ext: omni.kit.widget.versioning-1.3.4] shutdown
# [142.919s] [ext: omni.kit.window.popup_dialog-2.0.4] shutdown
# [142.919s] [ext: omni.kit.window.script_editor-1.5.0] shutdown
# [142.919s] [ext: omni.kit.mainwindow-0.0.0] shutdown
# [142.919s] [ext: omni.kit.menu.utils-1.0.2] shutdown
# [142.919s] [ext: omni.ui-2.5.3] shutdown
# [142.919s] [ext: omni.kit.renderer.core-0.0.0] shutdown
# [143.131s] [ext: omni.appwindow-1.0.0] shutdown
# [143.132s] [ext: omni.kit.search_core-1.0.0] shutdown
# [143.132s] [ext: omni.kit.usd_undo-0.1.0] shutdown
# [143.132s] [ext: omni.kit.thumbnails.images-0.1.0] shutdown
# [143.132s] [ext: omni.services.transport.server.http-1.0.0] shutdown
# [143.132s] [ext: omni.services.transport.server.base-1.0.0] shutdown
# [143.132s] [ext: omni.services.transport.client.http_async-1.0.0] shutdown
# [143.132s] [ext: omni.services.client-0.2.3] shutdown
# [143.132s] [ext: omni.services.core-1.1.1] shutdown
# [143.132s] [ext: omni.kit.test-0.0.0] shutdown
# [143.132s] [ext: omni.kit.loop-isaac-0.1.0] shutdown
# [143.132s] [ext: omni.usd.schema.isaac-0.1.1] shutdown
# [143.132s] [ext: omni.kit.numpy.common-0.1.0] shutdown
# [143.132s] [ext: omni.kit.widget.stage_icons-1.0.2] shutdown
# [143.132s] [ext: carb.audio-0.1.0] shutdown
# [143.132s] [ext: omni.renderer-rtx-0.0.0] shutdown
# [143.133s] [ext: omni.client-0.1.0] shutdown
# [143.153s] [ext: omni.assets.plugins-0.0.0] shutdown
# [143.153s] [ext: omni.gpu_foundation-0.0.0] shutdown
# 2022-05-02 21:25:59 [143,146ms] [Warning] [carb] unloadPlugin: Failed to find a plugin at: /home/student/.local/share/ov/pkg/isaac_sim-2021.2.1/kit/plugins/carb_gfx/libcarb.xr.plugin.so.
# 2022-05-02 21:25:59 [143,146ms] [Warning] [carb] unloadPlugin: Failed to find a plugin at: /home/student/.local/share/ov/pkg/isaac_sim-2021.2.1/kit/plugins/rtx/librtx.xrtools.plugin.so.
# [143.153s] [ext: omni.hydra.rtx-0.1.0] shutdown
# [143.153s] [ext: omni.hydra.scene_delegate-0.1.0] shutdown
# 2022-05-02 21:25:59 [143,147ms] [Warning] [carb] unloadPlugin: Failed to find a plugin at: /home/student/.local/share/ov/pkg/isaac_sim-2021.2.1/kit/plugins/libomni.gpucompute-cuda.plugin.so.
# 2022-05-02 21:25:59 [143,147ms] [Warning] [carb] unloadPlugin: Failed to find a plugin at: /home/student/.local/share/ov/pkg/isaac_sim-2021.2.1/kit/plugins/libomni.gpucompute-d3dvk.plugin.so.
# [143.153s] [ext: omni.kit.agent-0.1.0] shutdown
# [143.153s] [ext: omni.kit.async_engine-0.0.0] shutdown
# [143.153s] [ext: omni.kit.commands-0.0.0] shutdown
# [143.153s] [ext: omni.kit.pip_archive-0.0.0] shutdown
# [143.153s] [ext: omni.kit.pipapi-0.0.0] shutdown
# [143.153s] [ext: omni.services.facilities.base-1.0.0] shutdown
# [143.153s] [ext: omni.services.transport.client.base-1.1.0] shutdown
# [143.154s] [ext: omni.stats-0.0.0] shutdown
# [143.154s] [ext: omni.timeline-1.0.2] shutdown
# [143.154s] [ext: omni.usd.schema.anim-0.0.0] shutdown
# [143.154s] [ext: omni.usd.schema.semantics-0.0.0] shutdown
# [143.154s] [ext: omni.usd.schema.audio-0.0.0] shutdown
# [143.154s] [ext: omni.usd.libs-1.0.0] shutdown
# [143.155s] [ext: omni.usd.config-1.0.0] shutdown
# Simulation App Shutdown Complete
